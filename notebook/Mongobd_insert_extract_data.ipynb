# %% [markdown]
# ## 1. Read Housing data, make it ready to bulk insert into MongoDB

# %%
import pandas as pd

# %%
housing_df = pd.read_csv(r'C:\Users\anjik\Desktop\iNeuron_FSDS\ML_end_to_end_projects\Real_Estate_House_Price_Prediction\housing.csv',
                         sep=',',lineterminator='\n', header=0)
housing_df.head(2)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY

# %%
#housing_df["ocean_proximity"].value_counts()

# %% [markdown]
# #### NOTE: since MongoDB accept entries in json format/as dictionary; i converted each row of housing_df into json format/dictionary using df.to_dict('records')

# %%
data_slice = housing_df.head()
slice_dict = data_slice.to_dict('records')
# show first 2 rows of data
slice_dict = data_slice.to_dict('records')
slice_dict[:2]
# Out:
# [{'longitude': -122.23,
#   'latitude': 37.88,
#   'housing_median_age': 41.0,
#   'total_rooms': 880.0,
#   'total_bedrooms': 129.0,
#   'population': 322.0,
#   'households': 126.0,
#   'median_income': 8.3252,
#   'median_house_value': 452600.0,
#   'ocean_proximity': 'NEAR BAY'},
#  {'longitude': -122.22,
#   'latitude': 37.86,
#   'housing_median_age': 21.0,
#   'total_rooms': 7099.0,
#   'total_bedrooms': 1106.0,
#   'population': 2401.0,
#   'households': 1138.0,
#   'median_income': 8.3014,
#   'median_house_value': 358500.0,
#   'ocean_proximity': 'NEAR BAY'}]

# %% [markdown]
# ## 2. dictionary of housing_df

# %%
diction = housing_df.to_dict('records') # diction holds housing data as list of dictionaries (each row as dictionary)
diction[3:4]
# Out:
# [{'longitude': -122.25,
#   'latitude': 37.85,
#   'housing_median_age': 52.0,
#   'total_rooms': 1274.0,
#   'total_bedrooms': 235.0,
#   'population': 558.0,
#   'households': 219.0,
#   'median_income': 5.6431,
#   'median_house_value': 341300.0,
#   'ocean_proximity': 'NEAR BAY'}]

# %% [markdown]
# ### !pip install pymongo[srv]
# ### !pip install dnspython

# %%
# !pip install pymongo[srv]

# %%
import pymongo
import dns

# %% [markdown]
# ## 3. connect with Mongoclient, create database and collection instance

# %%
client = pymongo.MongoClient("mongodb+srv://gellima:mongohousing@cluster0.7sadqvu.mongodb.net/?retryWrites=true&w=majority")
db = client.test
print(db)
# Out:
# Database(MongoClient(host=['ac-dhkqjhq-shard-00-01.7sadqvu.mongodb.net:27017', 'ac-dhkqjhq-shard-00-00.7sadqvu.mongodb.net:27017', 'ac-dhkqjhq-shard-00-02.7sadqvu.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-zygrm6-shard-0', tls=True), 'test')

# %%
# Making a Connection with MongoClient
#client = pymongo.MongoClient("mongodb+srv://mgelli:mongohousing@cluster0.7sadqvu.mongodb.net/?retryWrites=true&w=majority",
                             #tls =True, tlsAllowInvalidCertificates=True)
#db = client.test

#print(db)

# %%
# create database instance; caution, it should be like dictionary[key]
database = client["HousingDB1"]
database
# Out:
# Database(MongoClient(host=['ac-dhkqjhq-shard-00-01.7sadqvu.mongodb.net:27017', 'ac-dhkqjhq-shard-00-00.7sadqvu.mongodb.net:27017', 'ac-dhkqjhq-shard-00-02.7sadqvu.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-zygrm6-shard-0', tls=True), 'HousingDB1')

# %%
client.list_database_names()
# Out:
# ['admin', 'local']

# %%
# create collection instance
collection1 = database['housing.collection_set']
collection1
# Out:
# Collection(Database(MongoClient(host=['ac-dhkqjhq-shard-00-01.7sadqvu.mongodb.net:27017', 'ac-dhkqjhq-shard-00-00.7sadqvu.mongodb.net:27017', 'ac-dhkqjhq-shard-00-02.7sadqvu.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-zygrm6-shard-0', tls=True), 'HousingDB1'), 'housing.collection_set')

# %% [markdown]
# ## 4. create a single document/instance; add to housing.collection

# %%
one_value = {'longitude': -122.25,
  'latitude': 37.85,
  'housing_median_age': 52.0,
  'total_rooms': 1274.0,
  'total_bedrooms': 235.0,
  'population': 558.0,
  'households': 219.0,
  'median_income': 5.6431,
  'median_house_value': 341300.0,
  'ocean_proximity': 'NEAR BAY'}

# %%
columns = [key for key in one_value.keys()]
columns
# Out:
# ['longitude',
#  'latitude',
#  'housing_median_age',
#  'total_rooms',
#  'total_bedrooms',
#  'population',
#  'households',
#  'median_income',
#  'median_house_value',
#  'ocean_proximity',
#  '_id']

# %%
collection1.insert_one(one_value)

# %% [markdown]
# ## 5. Delete the above document/instance; from housing.collection

# %%
collection1.delete_one(one_value)

# %% [markdown]
# ### pip install pymongo
# ### pip install dnspython

# %%
collection1.insert_one(one_value)

# %% [markdown]
# ## 6. now insert dictionary of housing_df using insert_many

# %%
# create document instance
document1 = diction
document1
# Out:
# [{'longitude': -122.23,
#   'latitude': 37.88,
#   'housing_median_age': 41.0,
#   'total_rooms': 880.0,
#   'total_bedrooms': 129.0,
#   'population': 322.0,
#   'households': 126.0,
#   'median_income': 8.3252,
#   'median_house_value': 452600.0,
#   'ocean_proximity': 'NEAR BAY'},
#  {'longitude': -122.22,
#   'latitude': 37.86,
#   'housing_median_age': 21.0,
#   'total_rooms': 7099.0,
#   'total_bedrooms': 1106.0,
#   'population': 2401.0,
#   'households': 1138.0,
#   'median_income': 8.3014,
#   'median_house_value': 358500.0,
#   'ocean_proximity': 'NEAR BAY'},
#  {'longitude': -122.24,
#   'latitude': 37.85,
#   'housing_median_age': 52.0,
#   'total_rooms': 1467.0,
#   'total_bedrooms': 190.0,
#   'population': 496.0,
#   'households': 177.0,
#   'median_income': 7.2574,
#   'median_house_value': 352100.0,
#   'ocean_proximity': 'NEAR BAY'},
#  {'longitude': -122.25,
#   'latitude': 37.85,
#   'housing_median_age': 52.0,
#   'total_rooms': 1274.0,
# ...

# %%
collection1.insert_many(document1)

# %% [markdown]
# ## write function to insert data into Mongodb

# %%
def insert_data_into_mongodb(data:dict):
    '''this function inserts single or multilple records of data into mongodb in the form of dictionary'''
    try:
